# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import io
import pandas as murales
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/Fifa_world_cup_matches.csv")
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
# ...

# %%
from matplotlib import pyplot as plt
_df_3['total attempts team2'].plot(kind='hist', bins=20, title='total attempts team2')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %%
data['conceded team2'].mean()
# Out:
# 1.578125

# %%
data['conceded team2'].median()
# Out:
# 1.0

# %%
data['conceded team2'].mode()
# Out:
# 0    1
# Name: conceded team2, dtype: int64

# %%
data['conceded team2'].std()
# Out:
# 1.5512891464433753

# %%
sns.distplot(data['conceded team2'])
# Out:
# <ipython-input-10-fe71d04afa37>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['conceded team2'])
# <Axes: xlabel='conceded team2', ylabel='Density'>

# %%
sns.boxplot(x=data['conceded team2'])
# Out:
# <Axes: xlabel='conceded team2'>

# %%
data.corr()
# Out:
# <ipython-input-12-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                    number of goals team1  \
# number of goals team1                           1.000000
# number of goals team2                           0.018927
# total attempts team1                            0.400841
# total attempts team2                           -0.198041
# conceded team1                                  0.018927
# ...                                                  ...
# own goals team2                                -0.047324
# forced turnovers team1                         -0.014106
# forced turnovers team2                          0.027506
# defensive pressures applied team1              -0.081799
# defensive pressures applied team2               0.348401
#
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <ipython-input-13-8b96879b4d02>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
data.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
data['assists team2'].value_counts()
# Out:
# 0    31
# 1    23
# 2     7
# 3     2
# 4     1
# Name: assists team2, dtype: int64

# %%
sns.countplot(data['assists team2'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# CLASE 7

# %%
data['category'].unique()
# Out:
# array(['Group A', 'Group B', 'Group C', 'Group D', 'Group F', 'Group E',
#        'Group G', 'Group H', 'Round of 16', 'Quarter-final', 'Semi-final',
#        'Play-off for third place', 'Final'], dtype=object)

# %%
data.replace('Semi-final', 'Semi-Final', inplace=True)
data.replace('Play-off for third place', 'Play-off for 3° place', inplace=True)

# %%
data['category'].unique()
# Out:
# array(['Group A', 'Group B', 'Group C', 'Group D', 'Group F', 'Group E',
#        'Group G', 'Group H', 'Round of 16', 'Quarter-final', 'Semi-Final',
#        'Play-off for 3° place', 'Final'], dtype=object)

# %%
data['category'].value_counts()
# Out:
# Round of 16              8
# Group A                  6
# Group B                  6
# Group C                  6
# Group D                  6
# Group F                  6
# Group E                  6
# Group G                  6
# Group H                  6
# Quarter-final            4
# Semi-Final               2
# Play-off for 3° place    1
# Final                    1
# Name: category, dtype: int64

# %%
data.columns.unique
# Out:
# <bound method Index.unique of Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
# ...

# %%
data.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
# ...

# %%
dicc_remplazo={'team1':'Team 1',
               'team2':'Team 2',
               'possession team1':'Possession Team 1',
               'possession team2':  'Possession Peam 2',
               'possession in contest': 'Possession in Contest',
               'number of goals team1': 'Number of Goals Team 1',
               'number of goals team2':  'Number of Goals Team 2',
               'date': 'Date',
               'hour':'Hour',
               'category':'Category',
               'total attempts team1': 'Total Attempts Team 1',
               'total attempts team2':'Total Attempts Team 2',
               'conceded team1': 'Conceded Team 1',
               'conceded team2':'Conceded Team 2',
               'goal inside the penalty area team1':'Goal Inside The Penalty Area Team 1',
               'goal inside the penalty area team2':'Goal Inside The Penalty Area Team 2',
               'goal outside the penalty area team1':'Goal Outside The Penalty Area Team 1',
               'goal outside the penalty area team2':'Goal Outside The Penalty Area Team 2',
               'assists team1':'Assists Team 1',
               'assists team2':'Assists Team 2',
               'on target attempts team1':'On Target Attempts Team 1',
               'on target attempts team2':'On Target Attempts Team 2',
               'off target attempts team1':'Off Target Attempts Team 1',
               'off target attempts team2':'Off Target Attempts Team 2',
               'attempts inside the penalty area team1':'Attempts Inside The Penalty Area Team 1',
               'attempts inside the penalty area  team2':'Attempts Inside The Penalty Area Team 2',
               'attempts outside the penalty area  team1':'Attempts Outside The Penalty Area Team 1',
               'attempts outside the penalty area  team2':'Attempts Outside The Penalty Area Team 2',
               'left channel team1':'Left Channel Team 1',
               'left channel team2':'Left Channel Team 2',
               'left inside channel team1':'Left Inside Channel Team 1',
               'left inside channel team2':'Left Inside Channel Team 2',
               'central channel team1':'Central Channel Team 1',
               'central channel team2':'Central Channel Team 2',
               'right inside channel team1':'Right Inside Channel Team 1',
               'right inside channel team2':'Right Inside Channel Team 2',
               'right channel team1':'Right Channel Team 1',
               'right channel team2':'Right Channel Team 2',
               'total offers to receive team1':'Total Offers To Receive Team 1',
               'total offers to receive team2':'Total Offers To Receive Team 2',
               'inbehind offers to receive team1':'Inbehind Offers To Receive Team 1',
               'inbehind offers to receive team2':'Inbehind Offers To Receive Team 2',
               'inbetween offers to receive team1':'Inbetween Offers To Receive Team 1',
               'inbetween offers to receive team2':'Inbetween Offers To Receive Team 2',
               'infront offers to receive team1':'Infront Offers To Receive Team 1',
               'infront offers to receive team2':'Infront Offers To Receive Team 2',
               'receptions between midfield and defensive lines team1':'Receptions Between Midfield And Defensive Lines Team 1',
               'receptions between midfield and defensive lines team2':'Receptions Between Midfield And Defensive Lines Team 2',
               'attempted line breaks team1':'Attempted Line Breaks Team 1',
               'attempted line breaks team2':'Attempted Line Breaks Team 2',
               'completed line breaksteam1':'Completed Line Breaks Team 1',
               'completed line breaks team2':'Completed Line Breaks Team 2',
               'attempted defensive line breaks team1':'Attempted Defensive Line Breaks Team 1',
               'attempted defensive line breaks team2':'Attempted Defensive Line Breaks Team 2',
               'completed defensive line breaksteam1':'Completed Defensive Line Breaks Team 1',
               'completed defensive line breaks team2':'Completed Defensive Line Breaks Team 2',
               'yellow cards team1':'Yellow Cards Team 1',
               'yellow cards team2':'Yellow Cards Team 2',
               'red cards team1':'Red Cards Team 1',
               'red cards team2': 'Red Cards Team 2',
               'fouls against team1':'Fouls against team 1',
               'fouls against team2':'Fouls against team 2',
               'offsides team1':'Offsides Team 1',
               'offsides team2':'Offsides Team 2',
               'passes team1':'Passes Team 1',
               'passes team2':'Passes Team 2',
               'passes completed team1':'Passes Completed Team 1',
               'passes completed team2':'Passes Completed Team 2',
               'crosses team1':'Crosses Team 1',
               'crosses team2':'Crosses Team 2',
               'crosses completed team1':'Crosses Completed Team 1',
               'crosses completed team2':'Crosses Completed Team 2',
               'switches of play completed team1':'Switches Of Play Completed Team 1',
               'switches of play completed team2':'Switches Of Play Completed Team 2',
               'corners team1':'Corners Team 1',
               'corners team2':'Corners Team 2',
               'free kicks team1':'Free Kicks Team 1',
               'free kicks team2':'Free Kicks Team 2',
               'penalties scored team1':'Penalties Scored Team 1',
               'penalties scored team2':'Penalties Scored Team 2',
               'goal preventions team1':'Goal Preventions Team 1',
               'goal preventions team2':'Goal Preventions Team 2',
               'own goals team1':'Own Goals Team 1',
               'own goals team2':'Own Goals Team 2',
               'forced turnovers team1':'Forced Turnovers Team 1',
               'forced turnovers team2':'Forced Turnovers Team 2',
               'defensive pressures applied team1':'Defensive Pressures Applied Team 1',
               'defensive pressures applied team2':'Defensive Pressures Applied Team 2',

}

# %%
data.replace(dicc_remplazo, inplace=True)

# %%
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...
